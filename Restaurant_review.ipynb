# %%
# %pip install cohere
# Out:
# Collecting cohere
#   Using cached cohere-1.3.9.tar.gz (8.9 kB)
# Requirement already satisfied: requests in c:\users\acer\anaconda3\lib\site-packages (from cohere) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests->cohere) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests->cohere) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests->cohere) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\acer\anaconda3\lib\site-packages (from requests->cohere) (3.0.4)
# Building wheels for collected packages: cohere
#   Building wheel for cohere (setup.py): started
#   Building wheel for cohere (setup.py): finished with status 'done'
#   Created wheel for cohere: filename=cohere-1.3.9-cp38-cp38-win_amd64.whl size=9459 sha256=5f4925dea6c685683738bec81d52741b948ffaa61291602b8844c8672dde5c6c
#   Stored in directory: c:\users\acer\appdata\local\pip\cache\wheels\ff\e7\08\7262268671cab26185389b733777907b447bba38db4232196c
# Successfully built cohere
# Installing collected packages: cohere
# Successfully installed cohere-1.3.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cohere
from cohere.classify import Example
import json

LIMIT = 10000

# %%
def load_data(filepath, nrows=None):
    with open(filepath, encoding="utf8") as jsonfile:
        count = 0
        items = []
        line = jsonfile.readline()
        while (nrows is None or count < nrows) and line:
            count += 1
            obj = json.loads(line)
            items.append(obj)
            line = jsonfile.readline()
        return pd.DataFrame(items)

reviews = load_data('Dataset/yelp_academic_dataset_review.json', LIMIT)
print('Review dataset size = {}'.format(reviews.shape[0]))

business = load_data('../Dataset/yelp_academic_dataset_business.json')
print('Business dataset size = {}'.format(business.shape[0]))
# Out:
# Review dataset size = 10000

# %%
reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1  8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A
# 2  NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw
# 3  T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew
# 4  sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA
#
#    stars  useful  funny  cool  \
# 0    4.0       3      1     1
# 1    4.0       1      0     0
# 2    5.0       0      0     0
# 3    2.0       1      1     1
# 4    4.0       0      0     0
#
#                                                 text                 date
# 0  Apparently Prides Osteria had a rough summer a...  2014-10-11 03:34:02
# 1  This store is pretty good. Not as great as Wal...  2015-07-03 20:38:25
# 2  I called WVM on the recommendation of a couple...  2013-05-28 20:38:06
# 3  I've stayed at many Marriott and Renaissance M...  2010-01-08 02:29:15
# 4  The food is always great here. The service fro...  2011-07-28 18:05:01

# %%
reviews.shape
# Out:
# (10000, 9)

# %%
reviews.isnull().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
review_1 = reviews[['business_id', 'stars', 'text']]
review_2 = review_1.reset_index(drop=True)

# %%
review_2.head(50)
# Out:
#                business_id  stars  \
# 0   buF9druCkbuXLX526sGELQ    4.0
# 1   RA4V8pr014UyUbDvI-LW2A    4.0
# 2   _sS2LBIGNT5NQb6PD1Vtjw    5.0
# 3   0AzLzHfOJgL7ROwhdww2ew    2.0
# 4   8zehGz9jnxPqXtOc7KaJxA    4.0
# 5   xGXzsc-hzam-VArK6eTvtw    1.0
# 6   EXOsmAB1s71WePlQk0WZrA    2.0
# 7   DbXHNl890xSXNiyRczLWAg    5.0
# 8   mD-A9KOWADXvfrZfwDs-jw    4.0
# 9   EEHhKSxUvJkoPSzeGKkpVg    5.0
# 10  WQFn1A7-UAA4JT5YWiop_w    1.0
# 11  iZxfWlfNPXV_0S1xO8QNSQ    2.0
# 12  TA1KUSCu8GkWP9w0rmElxw    4.0
# 13  wZgUAuDuEGPEzKK-PsngKQ    1.0
# 14  mw_qxZJraNu7Q6u0GkcMew    5.0
# 15  gGvNgShksetPoimyKV8I9Q    4.0
# 16  6Hm2FmfLcU_M91TrZI5htA    5.0
# 17  KXCXaF5qimmtKKqnPc_LQA    1.0
# 18  zmZ3HkVCeZPBefJJxzdJ7A    4.0
# 19  ZW7aI5FO_3q_vSzI4_zx-Q    5.0
# 20  mOnesB4IF9j6-ZmHoOHOig    4.0
# 21  MJYb0fioM-X7jc_0RIYyqQ    4.0
# 22  jMz_y_-cWMfiZF7Q5snE6Q    5.0
# 23  I2OblwJG8_XzFxxoHU0vVQ    4.0
# 24  WDGeeyeK7bG0cvq_ZglAdA    1.0
# 25  ISBs1ARjIFCXGWqPmGSMog    5.0
# 26  _gOz7-aHMyGUHOtjDrEv2w    2.0
# 27  AW_dMex_BXFzgBJFxAjDuQ    5.0
# 28  tiKV9b0b2kpaGm5a-nd1ig    4.0
# 29  I-qL4zwr62710OJBtVv28A    4.0
# 30  -_GnwXmzC3DXsHR9nyaC2g    3.0
# 31  CF2k7avLtV246iJwp16J7Q    5.0
# 32  Qydynzc1ApxsSkVNEgPs9A    1.0
# 33  dWBKYjQ3q2v2dOjsfLLxDg    1.0
# 34  IdXHHEUH4ebcxdRxCo3JNw    3.0
# 35  luOZQ9YBrWwP8mYrS4rNoA    4.0
# 36  p2BkIrOuIsxGqtV0lwOZUw    3.0
# 37  AvXqLbcGCxdIEF_qZTY0Kw    5.0
# 38  xPo2OA5_wQgUEzAr-1o1Lg    5.0
# 39  vRrDTIW9IFBO4cc3laazUw    5.0
# 40  M4jkJHewQXZvDV34Tuon8g    1.0
# 41  WtDOs3a6k_oPJmwiDh4qBQ    2.0
# 42  H_RM2u1WWGU1HkKZrYq2Ow    5.0
# 43  zWp3VbtS1p6PEdOxImpL1A    5.0
# 44  Ld88I1LFRlxnFlQVIoHAJw    5.0
# 45  H_RM2u1WWGU1HkKZrYq2Ow    5.0
# 46  EuiU19EjhybpGLXqBzntgw    1.0
# 47  VPqWLp9kMiZEbctCebIZUA    3.0
# 48  J7KvI94QUxab29LLeG6bew    5.0
# 49  9P-lp3AWDXGayDqJz9VPwQ    2.0
#
#                                                  text
# 0   Apparently Prides Osteria had a rough summer a...
# 1   This store is pretty good. Not as great as Wal...
# 2   I called WVM on the recommendation of a couple...
# 3   I've stayed at many Marriott and Renaissance M...
# 4   The food is always great here. The service fro...
# 5   This place used to be a cool, chill place. Now...
# 6   The setting is perfectly adequate, and the foo...
# 7   Probably one of the better breakfast sandwiche...
# 8   I am definitely a fan of Sports Authority.  Th...
# 9   I work in the Pru and this is the most afforda...
# 10  They NEVER seem to get our \norder correct, se...
# 11  Disappointing. Bolt is a follow up of Fanny's ...
# 12  I have been here twice and have had really goo...
# 13  I wish I could give them zero stars. The call ...
# 14  This is a five-star restaurant if ever I have ...
# 15  Quickly stopped in for a UFC fight. I sat down...
# 16  I loved everything about this place. I've only...
# 17  Great coffee and pastries. Baristas are excell...
# 18  Nothing special but good enough.  I like anoth...
# 19  Definitely 5 stars for the donuts.  Our family...
# 20  I think their rice dishes are way better than ...
# 21  Best station to fill up around in my opinion. ...
# 22  Ordered the original tonkotsu base ramen and a...
# 23  I just had my lasik done last week and I am re...
# 24  Almost desolate restaurant and dingy evironmen...
# 25  I had a 1 hour massage tonight with Barbara. L...
# 26  When we first arrived at the Coco Key, we were...
# 27  Erika was amazing! After months of trying to f...
# 28  This place is truly a hidden gem (literally hi...
# 29  Am I crazy for giving anything MBTA-related fo...
# 30  3.5 stars! I got the avocado margarita and it ...
# 31  First time being here and I'm not going anywhe...
# 32  I love ale house. I'm here all the time. The 1...
# 33  This has not been a pleasant experience. Accor...
# 34  "A Bit Embarrassed"\n\nI'm not exactly sure wh...
# 35  This place has some of the BEST chinese take-o...
# 36  Just had Yalla for lunch today. I work on Krog...
# 37  Overall Recommendation:  If you like fried chi...
# 38  best pizza on a busy street! my kids love it. ...
# 39  So sad to learn they are demolishing this. Alw...
# 40  Had the worst experience there today when I tr...
# 41  I wanted this to be a great place, but I wasn'...
# 42  Incredible donuts. Sometimes you have to go ea...
# 43  New owner is raising the bar with designer wom...
# 44  Kudos to AutoNation! We had an oil change done...
# 45  Dont bother going to voodoo, just come here in...
# 46  Bummer. I was very disappointed.  So I finally...
# 47  Overall is good, is worth the line up I don't ...
# 48  It's a pleasure doing business with them. Very...
# 49  The ramen here is less than great. It came out...

# %%
import nltk
import re
from nltk import pos_tag, pos_tag_sents
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import sentiwordnet as swn
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk import sent_tokenize, word_tokenize, pos_tag

# %%
# 1. The text data in review dataset is cleaned and tokenized to sentences and then words
# 2. Tag all words with position tags and convert to wordnet tags
# 3. Lemmatize the words and create synsets
# 4. Compute sentiment score (positive score - negative score)
# 5. Return a sentiment polarity score: 1 = positive, 0 = negative

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('sentiwordnet')
 
lemmatizer = WordNetLemmatizer()
  
def convert_tag(tag):
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None
 
def clean_text(text):
    text = text.replace("<br />", " ")
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text)
    text = (re.sub('[\W]+', ' ', text.lower()) + ' '.join(emoticons).replace('-', ''))
    #text = text.decode("utf-8")
    return text

def compute_swn_polarity_score(text):
    sentiment_score = 0.0
    num_tokens = 0
    text = clean_text(text)
    sentences = sent_tokenize(text)
    for sentence in sentences:
        tagged_sentence = pos_tag(word_tokenize(sentence))
        for word, tag in tagged_sentence:
            wn_tag = convert_tag(tag)
            if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
                continue
            lemma = lemmatizer.lemmatize(word, pos=wn_tag)
            if not lemma:
                continue
            synsets = wn.synsets(lemma, pos=wn_tag)
            if not synsets:
                continue
            synset = synsets[0]
            swn_synset = swn.senti_synset(synset.name())
            sentiment_score += swn_synset.pos_score() - swn_synset.neg_score()
            num_tokens += 1
    # sum greater than 0 => positive sentiment
    if sentiment_score >= 0:
        return 1
    # All other scenarios => negative sentiment
    else:
        return 0
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!

# %%
# Create a new column 'polarity' with sentiment polarity as 1 (positive) or 0 (negative)
review_2['polarity'] = review_2['text'].apply(compute_swn_polarity_score)
review_2.head(50)
# Out:
#                business_id  stars  \
# 0   buF9druCkbuXLX526sGELQ    4.0
# 1   RA4V8pr014UyUbDvI-LW2A    4.0
# 2   _sS2LBIGNT5NQb6PD1Vtjw    5.0
# 3   0AzLzHfOJgL7ROwhdww2ew    2.0
# 4   8zehGz9jnxPqXtOc7KaJxA    4.0
# 5   xGXzsc-hzam-VArK6eTvtw    1.0
# 6   EXOsmAB1s71WePlQk0WZrA    2.0
# 7   DbXHNl890xSXNiyRczLWAg    5.0
# 8   mD-A9KOWADXvfrZfwDs-jw    4.0
# 9   EEHhKSxUvJkoPSzeGKkpVg    5.0
# 10  WQFn1A7-UAA4JT5YWiop_w    1.0
# 11  iZxfWlfNPXV_0S1xO8QNSQ    2.0
# 12  TA1KUSCu8GkWP9w0rmElxw    4.0
# 13  wZgUAuDuEGPEzKK-PsngKQ    1.0
# 14  mw_qxZJraNu7Q6u0GkcMew    5.0
# 15  gGvNgShksetPoimyKV8I9Q    4.0
# 16  6Hm2FmfLcU_M91TrZI5htA    5.0
# 17  KXCXaF5qimmtKKqnPc_LQA    1.0
# 18  zmZ3HkVCeZPBefJJxzdJ7A    4.0
# 19  ZW7aI5FO_3q_vSzI4_zx-Q    5.0
# 20  mOnesB4IF9j6-ZmHoOHOig    4.0
# 21  MJYb0fioM-X7jc_0RIYyqQ    4.0
# 22  jMz_y_-cWMfiZF7Q5snE6Q    5.0
# 23  I2OblwJG8_XzFxxoHU0vVQ    4.0
# 24  WDGeeyeK7bG0cvq_ZglAdA    1.0
# 25  ISBs1ARjIFCXGWqPmGSMog    5.0
# 26  _gOz7-aHMyGUHOtjDrEv2w    2.0
# 27  AW_dMex_BXFzgBJFxAjDuQ    5.0
# 28  tiKV9b0b2kpaGm5a-nd1ig    4.0
# 29  I-qL4zwr62710OJBtVv28A    4.0
# 30  -_GnwXmzC3DXsHR9nyaC2g    3.0
# 31  CF2k7avLtV246iJwp16J7Q    5.0
# 32  Qydynzc1ApxsSkVNEgPs9A    1.0
# 33  dWBKYjQ3q2v2dOjsfLLxDg    1.0
# 34  IdXHHEUH4ebcxdRxCo3JNw    3.0
# 35  luOZQ9YBrWwP8mYrS4rNoA    4.0
# 36  p2BkIrOuIsxGqtV0lwOZUw    3.0
# 37  AvXqLbcGCxdIEF_qZTY0Kw    5.0
# 38  xPo2OA5_wQgUEzAr-1o1Lg    5.0
# 39  vRrDTIW9IFBO4cc3laazUw    5.0
# 40  M4jkJHewQXZvDV34Tuon8g    1.0
# 41  WtDOs3a6k_oPJmwiDh4qBQ    2.0
# 42  H_RM2u1WWGU1HkKZrYq2Ow    5.0
# 43  zWp3VbtS1p6PEdOxImpL1A    5.0
# 44  Ld88I1LFRlxnFlQVIoHAJw    5.0
# 45  H_RM2u1WWGU1HkKZrYq2Ow    5.0
# 46  EuiU19EjhybpGLXqBzntgw    1.0
# 47  VPqWLp9kMiZEbctCebIZUA    3.0
# 48  J7KvI94QUxab29LLeG6bew    5.0
# 49  9P-lp3AWDXGayDqJz9VPwQ    2.0
#
#                                                  text  polarity
# 0   Apparently Prides Osteria had a rough summer a...         1
# 1   This store is pretty good. Not as great as Wal...         1
# 2   I called WVM on the recommendation of a couple...         1
# 3   I've stayed at many Marriott and Renaissance M...         1
# 4   The food is always great here. The service fro...         1
# 5   This place used to be a cool, chill place. Now...         0
# 6   The setting is perfectly adequate, and the foo...         1
# 7   Probably one of the better breakfast sandwiche...         1
# 8   I am definitely a fan of Sports Authority.  Th...         1
# 9   I work in the Pru and this is the most afforda...         1
# 10  They NEVER seem to get our \norder correct, se...         0
# 11  Disappointing. Bolt is a follow up of Fanny's ...         0
# 12  I have been here twice and have had really goo...         1
# 13  I wish I could give them zero stars. The call ...         0
# 14  This is a five-star restaurant if ever I have ...         0
# 15  Quickly stopped in for a UFC fight. I sat down...         1
# 16  I loved everything about this place. I've only...         1
# 17  Great coffee and pastries. Baristas are excell...         1
# 18  Nothing special but good enough.  I like anoth...         1
# 19  Definitely 5 stars for the donuts.  Our family...         1
# 20  I think their rice dishes are way better than ...         1
# 21  Best station to fill up around in my opinion. ...         1
# 22  Ordered the original tonkotsu base ramen and a...         1
# 23  I just had my lasik done last week and I am re...         0
# 24  Almost desolate restaurant and dingy evironmen...         1
# 25  I had a 1 hour massage tonight with Barbara. L...         0
# 26  When we first arrived at the Coco Key, we were...         0
# 27  Erika was amazing! After months of trying to f...         1
# 28  This place is truly a hidden gem (literally hi...         1
# 29  Am I crazy for giving anything MBTA-related fo...         0
# 30  3.5 stars! I got the avocado margarita and it ...         1
# 31  First time being here and I'm not going anywhe...         1
# 32  I love ale house. I'm here all the time. The 1...         0
# 33  This has not been a pleasant experience. Accor...         1
# 34  "A Bit Embarrassed"\n\nI'm not exactly sure wh...         0
# 35  This place has some of the BEST chinese take-o...         1
# 36  Just had Yalla for lunch today. I work on Krog...         1
# 37  Overall Recommendation:  If you like fried chi...         1
# 38  best pizza on a busy street! my kids love it. ...         1
# 39  So sad to learn they are demolishing this. Alw...         0
# 40  Had the worst experience there today when I tr...         0
# 41  I wanted this to be a great place, but I wasn'...         1
# 42  Incredible donuts. Sometimes you have to go ea...         0
# 43  New owner is raising the bar with designer wom...         1
# 44  Kudos to AutoNation! We had an oil change done...         0
# 45  Dont bother going to voodoo, just come here in...         0
# 46  Bummer. I was very disappointed.  So I finally...         0
# 47  Overall is good, is worth the line up I don't ...         1
# 48  It's a pleasure doing business with them. Very...         1
# 49  The ramen here is less than great. It came out...         0

# %%
def transform_review(review_2):
    review_3 = review_2.reset_index()
    review_3['stars'] = review_3['stars'].apply(lambda x: round(x,2))
    review_3['polarity'] = review_3['polarity'].apply(lambda x: round(x,2))
    review_3.rename(columns={'polarity':'net_positive_sentiment_score'}, inplace=True)
    review_3.rename(columns={'stars':'review_stars'}, inplace=True)
    return review_3
review_3 = transform_review(review_2)
review_3.head(50)
# Out:
#     index             business_id  review_stars  \
# 0       0  buF9druCkbuXLX526sGELQ           4.0
# 1       1  RA4V8pr014UyUbDvI-LW2A           4.0
# 2       2  _sS2LBIGNT5NQb6PD1Vtjw           5.0
# 3       3  0AzLzHfOJgL7ROwhdww2ew           2.0
# 4       4  8zehGz9jnxPqXtOc7KaJxA           4.0
# 5       5  xGXzsc-hzam-VArK6eTvtw           1.0
# 6       6  EXOsmAB1s71WePlQk0WZrA           2.0
# 7       7  DbXHNl890xSXNiyRczLWAg           5.0
# 8       8  mD-A9KOWADXvfrZfwDs-jw           4.0
# 9       9  EEHhKSxUvJkoPSzeGKkpVg           5.0
# 10     10  WQFn1A7-UAA4JT5YWiop_w           1.0
# 11     11  iZxfWlfNPXV_0S1xO8QNSQ           2.0
# 12     12  TA1KUSCu8GkWP9w0rmElxw           4.0
# 13     13  wZgUAuDuEGPEzKK-PsngKQ           1.0
# 14     14  mw_qxZJraNu7Q6u0GkcMew           5.0
# 15     15  gGvNgShksetPoimyKV8I9Q           4.0
# 16     16  6Hm2FmfLcU_M91TrZI5htA           5.0
# 17     17  KXCXaF5qimmtKKqnPc_LQA           1.0
# 18     18  zmZ3HkVCeZPBefJJxzdJ7A           4.0
# 19     19  ZW7aI5FO_3q_vSzI4_zx-Q           5.0
# 20     20  mOnesB4IF9j6-ZmHoOHOig           4.0
# 21     21  MJYb0fioM-X7jc_0RIYyqQ           4.0
# 22     22  jMz_y_-cWMfiZF7Q5snE6Q           5.0
# 23     23  I2OblwJG8_XzFxxoHU0vVQ           4.0
# 24     24  WDGeeyeK7bG0cvq_ZglAdA           1.0
# 25     25  ISBs1ARjIFCXGWqPmGSMog           5.0
# 26     26  _gOz7-aHMyGUHOtjDrEv2w           2.0
# 27     27  AW_dMex_BXFzgBJFxAjDuQ           5.0
# 28     28  tiKV9b0b2kpaGm5a-nd1ig           4.0
# 29     29  I-qL4zwr62710OJBtVv28A           4.0
# 30     30  -_GnwXmzC3DXsHR9nyaC2g           3.0
# 31     31  CF2k7avLtV246iJwp16J7Q           5.0
# 32     32  Qydynzc1ApxsSkVNEgPs9A           1.0
# 33     33  dWBKYjQ3q2v2dOjsfLLxDg           1.0
# 34     34  IdXHHEUH4ebcxdRxCo3JNw           3.0
# 35     35  luOZQ9YBrWwP8mYrS4rNoA           4.0
# 36     36  p2BkIrOuIsxGqtV0lwOZUw           3.0
# 37     37  AvXqLbcGCxdIEF_qZTY0Kw           5.0
# 38     38  xPo2OA5_wQgUEzAr-1o1Lg           5.0
# 39     39  vRrDTIW9IFBO4cc3laazUw           5.0
# 40     40  M4jkJHewQXZvDV34Tuon8g           1.0
# 41     41  WtDOs3a6k_oPJmwiDh4qBQ           2.0
# 42     42  H_RM2u1WWGU1HkKZrYq2Ow           5.0
# 43     43  zWp3VbtS1p6PEdOxImpL1A           5.0
# 44     44  Ld88I1LFRlxnFlQVIoHAJw           5.0
# 45     45  H_RM2u1WWGU1HkKZrYq2Ow           5.0
# 46     46  EuiU19EjhybpGLXqBzntgw           1.0
# 47     47  VPqWLp9kMiZEbctCebIZUA           3.0
# 48     48  J7KvI94QUxab29LLeG6bew           5.0
# 49     49  9P-lp3AWDXGayDqJz9VPwQ           2.0
#
#                                                  text  \
# 0   Apparently Prides Osteria had a rough summer a...
# 1   This store is pretty good. Not as great as Wal...
# 2   I called WVM on the recommendation of a couple...
# 3   I've stayed at many Marriott and Renaissance M...
# 4   The food is always great here. The service fro...
# 5   This place used to be a cool, chill place. Now...
# 6   The setting is perfectly adequate, and the foo...
# 7   Probably one of the better breakfast sandwiche...
# 8   I am definitely a fan of Sports Authority.  Th...
# 9   I work in the Pru and this is the most afforda...
# 10  They NEVER seem to get our \norder correct, se...
# 11  Disappointing. Bolt is a follow up of Fanny's ...
# 12  I have been here twice and have had really goo...
# 13  I wish I could give them zero stars. The call ...
# 14  This is a five-star restaurant if ever I have ...
# 15  Quickly stopped in for a UFC fight. I sat down...
# 16  I loved everything about this place. I've only...
# 17  Great coffee and pastries. Baristas are excell...
# 18  Nothing special but good enough.  I like anoth...
# 19  Definitely 5 stars for the donuts.  Our family...
# 20  I think their rice dishes are way better than ...
# 21  Best station to fill up around in my opinion. ...
# 22  Ordered the original tonkotsu base ramen and a...
# 23  I just had my lasik done last week and I am re...
# 24  Almost desolate restaurant and dingy evironmen...
# 25  I had a 1 hour massage tonight with Barbara. L...
# 26  When we first arrived at the Coco Key, we were...
# 27  Erika was amazing! After months of trying to f...
# 28  This place is truly a hidden gem (literally hi...
# 29  Am I crazy for giving anything MBTA-related fo...
# 30  3.5 stars! I got the avocado margarita and it ...
# 31  First time being here and I'm not going anywhe...
# 32  I love ale house. I'm here all the time. The 1...
# 33  This has not been a pleasant experience. Accor...
# 34  "A Bit Embarrassed"\n\nI'm not exactly sure wh...
# 35  This place has some of the BEST chinese take-o...
# 36  Just had Yalla for lunch today. I work on Krog...
# 37  Overall Recommendation:  If you like fried chi...
# 38  best pizza on a busy street! my kids love it. ...
# 39  So sad to learn they are demolishing this. Alw...
# 40  Had the worst experience there today when I tr...
# 41  I wanted this to be a great place, but I wasn'...
# 42  Incredible donuts. Sometimes you have to go ea...
# 43  New owner is raising the bar with designer wom...
# 44  Kudos to AutoNation! We had an oil change done...
# 45  Dont bother going to voodoo, just come here in...
# 46  Bummer. I was very disappointed.  So I finally...
# 47  Overall is good, is worth the line up I don't ...
# 48  It's a pleasure doing business with them. Very...
# 49  The ramen here is less than great. It came out...
#
#     net_positive_sentiment_score
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1
# 5                              0
# 6                              1
# 7                              1
# 8                              1
# 9                              1
# 10                             0
# 11                             0
# 12                             1
# 13                             0
# 14                             0
# 15                             1
# 16                             1
# 17                             1
# 18                             1
# 19                             1
# 20                             1
# 21                             1
# 22                             1
# 23                             0
# 24                             1
# 25                             0
# 26                             0
# 27                             1
# 28                             1
# 29                             0
# 30                             1
# 31                             1
# 32                             0
# 33                             1
# 34                             0
# 35                             1
# 36                             1
# 37                             1
# 38                             1
# 39                             0
# 40                             0
# 41                             1
# 42                             0
# 43                             1
# 44                             0
# 45                             0
# 46                             0
# 47                             1
# 48                             1
# 49                             0

# %%
review_2.count()
# Out:
# text        10000
# polarity    10000
# dtype: int64

# %%
review_sample = review_2.sample(10000)

# %%
from sklearn.model_selection import train_test_split

# %%
sentences_train, sentences_test, labels_train, labels_test = train_test_split(
    list(review_sample['text']), list(review_sample['polarity']), test_size=0.25, random_state=42)

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(max_depth = 5) 
clf.fit(sentences_train, labels_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-10f099eb10ec> in <module>
#       1 clf = tree.DecisionTreeClassifier(max_depth = 5)
# ----> 2 clf.fit(sentences_train, labels_train)
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
#     158                                                             check_y_params))
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     427                 # :(
#     428                 check_X_params, check_y_params = validate_separately
# --> 429                 X = check_array(X, **check_X_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# c:\Users\acer\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'On my recent visit to Boston, I heard no less than three people raaave about Parish Cafe\'s gourmet sandwiches, invented by the chefs of some of the top restaurants in Beantown. Since I always have a place in my heart for a good sandwich, I had to check it out. \n\nThe outdoor seating area is obviously quite popular, as suggested by the sign near the entrance suggesting that anyone who wants to sit indoors does not need to stand in queue. You can\'t tell from the outside, but there is plenty of seating inside (though mostly for smaller parties) and the place has a somewhat pub-like feel. I took a seat at the bar, contemplated one of their many beers, and decided to ask for a suggestion from the bartender/server on what sandwich to try.\n\n"Well, it depends on what you\'re feeling like." And she was right, there is a type of sandwich for almost any type of appetite. Hearty meatloaf? The indulgent daily special of beer-battered, deep-fried mussels? Since I didn\'t feel like spending the rest of my day fighting a food coma, I settled on the "Blue Ginger" sandwich (created by Ming Tsai) - a grilled yet perfectly rare (and it is RED inside) tuna steak that is brushed with a teriyaki glaze. The condiments (lettuce, tomato, avocado slices, wasabi mayo) were the right combination, but the wasabi mayo wasn\'t strong enough to leave an impression or contrast. Overall, it was quite fresh, delicious, and well-seasoned...BUT (always a but w/ me, sorry that\'s how I roll) I think that focaccia is not structurally appropriate to hold together this surprisingly girthy sandwich. The bread, while perfectly toasted, herbed, and not too oily, inevitably gets weighed down and soggy from the fillings...leaving you with more sandwich on your hands than in your mouth. I took took to eating the rest of this with a fork and knife, which sorta defeats the whole point of it being a sandwich, doncha think?\n\nIn my opinion, the Asian slaw served w/ the Blue Ginger was sort of an afterthought. Although it had a nice sesame flavor, there was a missing acidic component, and the square-cut napa cabbage just looked sloppy (a thin julienne would have been much more appetizing to the eye).\n\nAfter I was done with my sandwich and fully satisfied, I was already thinking of what I wanted to try the next time I am in town.. But one question lingered: if the concept is to get the best chefs in Boston to create the menu...then why are so many of the sandwiches made by the Parish Cafe chefs???'

# %%
score = clf.score(sentences_test, labels_test)
print(f"Validation accuracy on medium is {100*score}%!")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-40-b5303ede2af2> in <module>
# ----> 1 score = clf.score(sentences_test, labels_test)
#       2 print(f"Validation accuracy on medium is {100*score}%!")
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     497         """
#     498         from .metrics import accuracy_score
# --> 499         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     500
#     501     def _more_tags(self):
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     424             The predicted classes, or the predict values.
#     425         """
# --> 426         check_is_fitted(self)
#     427         X = self._validate_X_predict(X, check_input)
#     428         proba = self.tree_.predict(X)
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\Users\acer\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
